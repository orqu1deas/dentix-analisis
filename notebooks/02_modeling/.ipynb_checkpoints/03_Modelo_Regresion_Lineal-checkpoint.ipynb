# %% [markdown]
# ## 1. Setup del Notebook

# %% [markdown]
# ### 1.1 Importación de Librerias

# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, TimeSeriesSplit, cross_val_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score, confusion_matrix, RocCurveDisplay
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm

from xgboost import XGBClassifier
import shap

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### 1.2 Lectura de Archivos

# %%
df = pd.read_csv("../../data/features/dentix_model_input.csv")
df.head()
# Out:
#    TRANSACTION ID  NO PERSONAS A CARGO  \
# 0         2016918            -0.292162
# 1         2016914            -0.292162
# 2         2016836            -0.292162
# 3         2016736            -0.292162
# 4         2016576            -0.292162
#
#    ANTIGUEDAD EN LA CIUDAD tiempo en residencia   ESTRATO  INGRESOS FIJOS  \
# 0                                     -1.001090  1.596071        0.036265
# 1                                      1.453012  0.631589        0.074066
# 2                                      0.634978 -0.332892       -0.036185
# 3                                     -0.455734  0.631589       -0.020435
# 4                                      1.180334  0.631589        0.055165
#
#    TOTAL INGRESOS  CUOTA DE CREDITOS  GASTOS DE SOSTENIMIENTO  TOTAL EGRESOS  \
# 0        0.065515          -0.008909                -0.006192      -0.009082
# 1        0.095785          -0.008914                -0.006263      -0.009089
# 2       -0.055565          -0.008914                -0.004870      -0.009020
# 3       -0.003674          -0.008877                -0.004586      -0.008977
# 4        0.069839          -0.008904                -0.006149      -0.009076
#
#     ACTIVOS   PASIVOS  MONTO PREAPROBADO    NO CREDITO  MONTO APROBADO  PLAZO  \
# 0  1.683621 -0.935995           3.188104  3.398612e+16        3.188433     36
# 1 -0.846057 -0.936087           0.310162  3.310281e+17        0.310251     36
# 2 -0.737642 -0.936087          -0.952535  3.397612e+16       -0.952551     18
# 3 -0.846057 -0.936087          -0.533317  3.310011e+17       -0.533298     36
# 4 -0.846057 -0.936087          -0.751478  3.310281e+17       -0.751478     36
#
#    MONTO DESEMBOLSO  IDENTIFICACION COMERCIAL      TASA  CUOTAMENSUAL  \
# 0          3.188108                1101203671  0.171785     -0.193257
# 1          0.310181                1045679685  0.171785     -0.193264
# 2         -0.952510                1026291187  0.171785     -0.193267
# 3         -0.533293                  31711538  0.171785     -0.193266
# 4         -0.751454                1083558670  0.171785     -0.193267
#
#    CODIGO CIIU  OPERACION MONEDA EXTRAGERA     SCORE  SEGURO   AVAL  \
# 0     1.699367                       False -0.497084   20986  69958
# 1     0.542254                       False  1.450843    7712  25710
# 2     0.597619                       False -0.687861    1889   6295
# 3     2.006661                       False  0.557206    3822  12741
# 4     0.597619                       False -1.963050    2816   9387
#
#    CODIGO CONFIRMACION CREDITO   PAGARE_ID  NUMERO CREDITO TESEO  \
# 0                       768277  40322901.0                768277
# 1                     50199432  40322628.0              50199432
# 2                     26657430  40321155.0              26657430
# 3                     81389650  40318689.0              81389650
# 4                     57688111  40310628.0              57688111
#
#    SALDO CAPITAL  SALDO VENCIDO  DIAS DE MORA  FRANJA DE MORA  \
# 0      -0.663694      -0.370764      -0.222886     01. Al dia
# 1       1.150411      -0.370764      -0.222886     01. Al dia
# 2      -0.219474      -0.370764      -0.222886     01. Al dia
# 3       0.215776      -0.370764      -0.222886     01. Al dia
# 4      -0.014447      -0.370764      -0.222886     01. Al dia
#
#    SALDO VENCIDO_LOG  DIAS DE MORA _LOG  TOTAL INGRESOS_LOG  \
# 0           -0.58416          -0.612929            1.789527
# 1           -0.58416          -0.612929            2.136953
# 2           -0.58416          -0.612929           -2.195607
# 3           -0.58416          -0.612929            0.550772
# 4           -0.58416          -0.612929            1.843704
#
#    INGRESOS FIJOS_LOG  MONTO APROBADO_LOG  MONTO PREAPROBADO_LOG  PASIVOS_LOG  \
# 0            1.651066            2.026063               2.025945    -0.164620
# 1            2.186823            0.616815               0.616754    -1.272372
# 2           -1.397658           -1.363989              -1.363968    -1.272372
# 3           -0.012940           -0.371507              -0.371527    -1.272372
# 4            1.944208           -0.801624              -0.801626    -1.272372
#
#    INGRESOS FIJOS_YJ  TOTAL INGRESOS_YJ  GASTOS DE SOSTENIMIENTO_YJ  \
# 0           1.550697           1.659905                   -1.342884
# 1           1.910448           1.884618                   -2.106196
# 2          -1.610168          -3.012882                    0.926897
# 3           0.101804           0.675282                    1.123095
# 4           1.753045           1.696270                   -1.094328
#
#    MONTO PREAPROBADO_YJ  MONTO APROBADO_YJ  MONTO DESEMBOLSO_YJ  SEGURO_YJ  \
# 0              2.274419           2.274626             2.274398   2.274323
# 1              0.587438           0.587502             0.587471   0.587420
# 2             -1.333679          -1.333696            -1.333657  -1.333466
# 3             -0.430452          -0.430443            -0.430414  -0.430477
# 4             -0.835670          -0.835676            -0.835637  -0.835645
#
#     AVAL_YJ  NIVEL ESTUDIOS_ORD  PROFESION_FREQ  CIUDAD_FREQ  COMERCIAL_FREQ  \
# 0  2.172652            0.842079        0.220835    -0.542495        0.977167
# 1  0.935561           -0.995517       -0.348914    -0.795561        1.627940
# 2 -0.703152           -0.995517       -0.931155     1.518785       -0.584690
# 3  0.103713           -0.995517       -0.495017    -0.450153        1.003198
# 4 -0.249351            0.842079        0.220835    -0.445501        2.651824
#
#    DEPARTAMENTO_FREQ  ESTADOCIVIL_Divorciado (a) / Separado (a)  \
# 0          -0.442162                                      False
# 1          -0.505167                                      False
# 2           1.470026                                      False
# 3          -0.565021                                      False
# 4          -0.505167                                      False
#
#    ESTADOCIVIL_Soltero (a)  ESTADOCIVIL_Unión libre  ESTADOCIVIL_Viudo (a)  \
# 0                     True                    False                  False
# 1                     True                    False                  False
# 2                    False                     True                  False
# 3                    False                     True                  False
# 4                     True                    False                  False
#
#    TIPO VIVIENDA_Familiar  TIPO VIVIENDA_Propia  \
# 0                    True                 False
# 1                   False                  True
# 2                    True                 False
# 3                   False                  True
# 4                   False                  True
#
#    TIPO VIVIENDA_Propia con crédito  \
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
#
#    ACTIVIDAD ECONÓMICA_Actividades de apoyo a la educación.  \
# 0                                               True
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    ACTIVIDAD ECONÓMICA_Actividades no diferenciadas de los hogares individuales como productores de bienes para uso propio.  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    ACTIVIDAD ECONÓMICA_Asalariados  \
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
#
#    ACTIVIDAD ECONÓMICA_Comercio al por mayor a cambio de una retribución o por contrata.  \
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                              False
#
#    ACTIVIDAD ECONÓMICA_Otras actividades de servicios personales n.c.p.  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
#    ACTIVIDAD ECONÓMICA_Otros tipos de comercio al por menor no realizado en establecimientos, puestos de venta o mercados.  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                               True
#
#    ACTIVIDAD ECONÓMICA_Pensionados  \
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
#
#    ACTIVIDAD ECONÓMICA_Rentistas de Capital, solo para personas naturales.  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    TIPO CONTRATO_Indefinido  TIPO CONTRATO_No Aplica  \
# 0                      True                    False
# 1                     False                     True
# 2                      True                    False
# 3                      True                    False
# 4                     False                    False
#
#    TIPO CONTRATO_Prestación de servicios  OCUPACIÓN_Empleado  \
# 0                                  False               False
# 1                                  False               False
# 2                                  False                True
# 3                                  False                True
# 4                                   True               False
#
#    OCUPACIÓN_Estudiante  OCUPACIÓN_Independiente  \
# 0                 False                     True
# 1                 False                     True
# 2                 False                    False
# 3                 False                    False
# 4                 False                     True
#
#    OCUPACIÓN_Pensionado / Jubilado  OCUPACIÓN_Rentista  OCUPACIÓN_Taxista   \
# 0                            False               False               False
# 1                            False               False               False
# 2                            False               False               False
# 3                            False               False               False
# 4                            False               False               False
#
#    OCUPACIÓN_Vendedora por catalogo  LUGAR NACIMIENTO_Albania  \
# 0                             False                     False
# 1                             False                     False
# 2                             False                     False
# 3                             False                     False
# 4                             False                     False
#
#    LUGAR NACIMIENTO_Argentina  LUGAR NACIMIENTO_Armenia  \
# 0                       False                     False
# 1                       False                     False
# 2                       False                     False
# 3                       False                     False
# 4                       False                     False
#
#    LUGAR NACIMIENTO_Belgica  LUGAR NACIMIENTO_China  \
# 0                     False                   False
# 1                     False                   False
# 2                     False                   False
# 3                     False                   False
# 4                     False                   False
#
#    LUGAR NACIMIENTO_Cocos (Keeling), Islas  LUGAR NACIMIENTO_Colombia  \
# 0                                    False                       True
# 1                                    False                       True
# 2                                    False                       True
# 3                                    False                       True
# 4                                    False                       True
#
#    LUGAR NACIMIENTO_Ecuador  LUGAR NACIMIENTO_España  \
# 0                     False                    False
# 1                     False                    False
# 2                     False                    False
# 3                     False                    False
# 4                     False                    False
#
#    LUGAR NACIMIENTO_Estados Unidos  LUGAR NACIMIENTO_Honduras  \
# 0                            False                      False
# 1                            False                      False
# 2                            False                      False
# 3                            False                      False
# 4                            False                      False
#
#    LUGAR NACIMIENTO_Italia  LUGAR NACIMIENTO_Mexico  LUGAR NACIMIENTO_Panama  \
# 0                    False                    False                    False
# 1                    False                    False                    False
# 2                    False                    False                    False
# 3                    False                    False                    False
# 4                    False                    False                    False
#
#    LUGAR NACIMIENTO_Puerto Rico  LUGAR NACIMIENTO_Venezuela  \
# 0                         False                       False
# 1                         False                       False
# 2                         False                       False
# 3                         False                       False
# 4                         False                       False
#
#    INCIDENCIAFORMALIZACION_Albania  INCIDENCIAFORMALIZACION_Argentina  \
# 0                            False                              False
# 1                            False                              False
# 2                            False                              False
# 3                            False                              False
# 4                            False                              False
#
#    INCIDENCIAFORMALIZACION_Armenia  INCIDENCIAFORMALIZACION_Belgica  \
# 0                            False                            False
# 1                            False                            False
# 2                            False                            False
# 3                            False                            False
# 4                            False                            False
#
#    INCIDENCIAFORMALIZACION_China  \
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
#
#    INCIDENCIAFORMALIZACION_Cocos (Keeling), Islas  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    INCIDENCIAFORMALIZACION_Colombia  INCIDENCIAFORMALIZACION_Ecuador  \
# 0                              True                            False
# 1                              True                            False
# 2                              True                            False
# 3                              True                            False
# 4                              True                            False
#
#    INCIDENCIAFORMALIZACION_España  INCIDENCIAFORMALIZACION_Estados Unidos  \
# 0                           False                                   False
# 1                           False                                   False
# 2                           False                                   False
# 3                           False                                   False
# 4                           False                                   False
#
#    INCIDENCIAFORMALIZACION_Honduras  INCIDENCIAFORMALIZACION_Italia  \
# 0                             False                           False
# 1                             False                           False
# 2                             False                           False
# 3                             False                           False
# 4                             False                           False
#
#    INCIDENCIAFORMALIZACION_Mexico  INCIDENCIAFORMALIZACION_Panama  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    INCIDENCIAFORMALIZACION_Puerto Rico  INCIDENCIAFORMALIZACION_Venezuela  \
# 0                                False                              False
# 1                                False                              False
# 2                                False                              False
# 3                                False                              False
# 4                                False                              False
#
#    CLINICA_Dentix BAQ Barranquilla  \
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
#
#    CLINICA_Dentix BAQ Barranquilla Portal del Prado  \
# 0                                             False
# 1                                              True
# 2                                             False
# 3                                             False
# 4                                              True
#
#    CLINICA_Dentix BGA Cañaveral  CLINICA_Dentix BGA Cl 35 Bucaramanga  \
# 0                         False                                  True
# 1                         False                                 False
# 2                         False                                 False
# 3                         False                                 False
# 4                         False                                 False
#
#    CLINICA_Dentix BOG Andino  CLINICA_Dentix BOG Autopista 104A Bogota  \
# 0                      False                                     False
# 1                      False                                     False
# 2                      False                                     False
# 3                      False                                     False
# 4                      False                                     False
#
#    CLINICA_Dentix BOG Avenida Chile  CLINICA_Dentix BOG C. C. Plaza Central  \
# 0                             False                                   False
# 1                             False                                   False
# 2                             False                                   False
# 3                             False                                   False
# 4                             False                                   False
#
#    CLINICA_Dentix BOG C.C. Titan  \
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
#
#    CLINICA_Dentix BOG CC Plaza de las Américas Bogotá  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    CLINICA_Dentix BOG Calle 90  CLINICA_Dentix BOG Cedritos - Bogotá  \
# 0                        False                                 False
# 1                        False                                 False
# 2                        False                                 False
# 3                        False                                 False
# 4                        False                                 False
#
#    CLINICA_Dentix BOG Chapinero  CLINICA_Dentix BOG Chia  \
# 0                         False                    False
# 1                         False                    False
# 2                         False                    False
# 3                         False                    False
# 4                         False                    False
#
#    CLINICA_Dentix BOG Colina Bogotá  CLINICA_Dentix BOG Diverplaza  \
# 0                             False                          False
# 1                             False                          False
# 2                             False                          False
# 3                             False                          False
# 4                             False                          False
#
#    CLINICA_Dentix BOG Fontibon  CLINICA_Dentix BOG Galerias  \
# 0                        False                        False
# 1                        False                        False
# 2                        False                        False
# 3                        False                        False
# 4                        False                        False
#
#    CLINICA_Dentix BOG Gran Estación  CLINICA_Dentix BOG Hayuelos  \
# 0                             False                        False
# 1                             False                        False
# 2                              True                        False
# 3                             False                        False
# 4                             False                        False
#
#    CLINICA_Dentix BOG Plaza Imperial  CLINICA_Dentix BOG Restrepo  \
# 0                              False                        False
# 1                              False                        False
# 2                              False                        False
# 3                              False                        False
# 4                              False                        False
#
#    CLINICA_Dentix BOG Santa Fe  CLINICA_Dentix BOG Unicentro  \
# 0                        False                         False
# 1                        False                         False
# 2                        False                         False
# 3                        False                         False
# 4                        False                         False
#
#    CLINICA_Dentix BOG Usaquen  CLINICA_Dentix BOG Venecia  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    CLINICA_Dentix CLO Av. 100 Cali  CLINICA_Dentix CLO Cali Chipichape  \
# 0                            False                               False
# 1                            False                               False
# 2                            False                               False
# 3                             True                               False
# 4                            False                               False
#
#    CLINICA_Dentix CLO Imbanaco  CLINICA_Dentix CLO Tulua  \
# 0                        False                     False
# 1                        False                     False
# 2                        False                     False
# 3                        False                     False
# 4                        False                     False
#
#    CLINICA_Dentix CTG Cartagena Cc Mallplaza  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    CLINICA_Dentix CUC Calle 13 Cúcuta  CLINICA_Dentix EOH Bello  \
# 0                               False                     False
# 1                               False                     False
# 2                               False                     False
# 3                               False                     False
# 4                               False                     False
#
#    CLINICA_Dentix EOH Centro Medellín  CLINICA_Dentix EOH Nutibara Medellin  \
# 0                               False                                 False
# 1                               False                                 False
# 2                               False                                 False
# 3                               False                                 False
# 4                               False                                 False
#
#    CLINICA_Dentix IBE Cra. 5 Ibague  CLINICA_Dentix MDE Av. Poblado Medellín  \
# 0                             False                                    False
# 1                             False                                    False
# 2                             False                                    False
# 3                             False                                    False
# 4                             False                                    False
#
#    CLINICA_Dentix MDE Envigado  CLINICA_Dentix MDE Fabricato Multialiado  \
# 0                        False                                     False
# 1                        False                                     False
# 2                        False                                     False
# 3                        False                                     False
# 4                        False                                     False
#
#    CLINICA_Dentix MDE Itagüi Mayorca  CLINICA_Dentix MTR Montería  \
# 0                              False                        False
# 1                              False                        False
# 2                              False                        False
# 3                              False                        False
# 4                              False                        False
#
#    CLINICA_Dentix MZL Cra. 23 Manizales  CLINICA_Dentix NVA Neiva  \
# 0                                 False                     False
# 1                                 False                     False
# 2                                 False                     False
# 3                                 False                     False
# 4                                 False                     False
#
#    CLINICA_Dentix PEI Pereira  CLINICA_Dentix PPN Popayán  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    CLINICA_Dentix PPN Popayán Campanario  CLINICA_Dentix PSO Pasto  \
# 0                                  False                     False
# 1                                  False                     False
# 2                                  False                     False
# 3                                  False                     False
# 4                                  False                     False
#
#    CLINICA_Dentix SMR Santa Marta  CLINICA_Dentix TUN Tunja  \
# 0                           False                     False
# 1                           False                     False
# 2                           False                     False
# 3                           False                     False
# 4                           False                     False
#
#    CLINICA_Dentix VUP Valledupar  CLINICA_Dentix VVC Primavera Villavicencio
# 0                          False                                       False
# 1                          False                                       False
# 2                          False                                       False
# 3                          False                                       False
# 4                          False                                       False

# %% [markdown]
# ## 2. Preparación de Datos

# %% [markdown]
# ### 2.1 Comprensión inicial

# %%
yj_cols = [col for col in df.columns if col.endswith("_YJ")]

onehot_cols = df.select_dtypes(include=['bool']).columns.tolist()

other_cols = ['TRANSACTION ID', 'ESTRATO', 'SCORE', 'CUOTA DE CREDITOS',
              'TOTAL EGRESOS', 'ACTIVOS', 'PLAZO', 'TASA', 'CUOTAMENSUAL',
              'NIVEL ESTUDIOS_ORD', 'PROFESION_FREQ', 'CIUDAD_FREQ',
              'COMERCIAL_FREQ', 'DEPARTAMENTO_FREQ']

cols_finales = yj_cols + onehot_cols + other_cols

df0 = df[cols_finales].copy()
df0 = df0.set_index("TRANSACTION ID")

pattern = re.compile(r"^INCIDENCIA[\s_]*FORMALIZACION", re.IGNORECASE)

cols_to_drop = [c for c in df0.columns if pattern.search(c)]
print("A borrar:", cols_to_drop)

if not cols_to_drop:
    pattern2 = re.compile(r"^INCIDENCIA[\s_]*FORMALIZACION.*_YJ$", re.IGNORECASE)
    cols_to_drop = [c for c in df_yj_onehot.columns if pattern2.search(c)]
    print("Variante _YJ a borrar:", cols_to_drop)

df0 = df0.drop(columns=cols_to_drop)
df0.head()
# Out:
# A borrar: ['INCIDENCIAFORMALIZACION_Albania', 'INCIDENCIAFORMALIZACION_Argentina', 'INCIDENCIAFORMALIZACION_Armenia', 'INCIDENCIAFORMALIZACION_Belgica', 'INCIDENCIAFORMALIZACION_China', 'INCIDENCIAFORMALIZACION_Cocos (Keeling), Islas', 'INCIDENCIAFORMALIZACION_Colombia', 'INCIDENCIAFORMALIZACION_Ecuador', 'INCIDENCIAFORMALIZACION_España', 'INCIDENCIAFORMALIZACION_Estados Unidos', 'INCIDENCIAFORMALIZACION_Honduras', 'INCIDENCIAFORMALIZACION_Italia', 'INCIDENCIAFORMALIZACION_Mexico', 'INCIDENCIAFORMALIZACION_Panama', 'INCIDENCIAFORMALIZACION_Puerto Rico', 'INCIDENCIAFORMALIZACION_Venezuela']
#                 INGRESOS FIJOS_YJ  TOTAL INGRESOS_YJ  \
# TRANSACTION ID
# 2016918                  1.550697           1.659905
# 2016914                  1.910448           1.884618
# 2016836                 -1.610168          -3.012882
# 2016736                  0.101804           0.675282
# 2016576                  1.753045           1.696270
#
#                 GASTOS DE SOSTENIMIENTO_YJ  MONTO PREAPROBADO_YJ  \
# TRANSACTION ID
# 2016918                          -1.342884              2.274419
# 2016914                          -2.106196              0.587438
# 2016836                           0.926897             -1.333679
# 2016736                           1.123095             -0.430452
# 2016576                          -1.094328             -0.835670
#
#                 MONTO APROBADO_YJ  MONTO DESEMBOLSO_YJ  SEGURO_YJ   AVAL_YJ  \
# TRANSACTION ID
# 2016918                  2.274626             2.274398   2.274323  2.172652
# 2016914                  0.587502             0.587471   0.587420  0.935561
# 2016836                 -1.333696            -1.333657  -1.333466 -0.703152
# 2016736                 -0.430443            -0.430414  -0.430477  0.103713
# 2016576                 -0.835676            -0.835637  -0.835645 -0.249351
#
#                 OPERACION MONEDA EXTRAGERA  \
# TRANSACTION ID
# 2016918                              False
# 2016914                              False
# 2016836                              False
# 2016736                              False
# 2016576                              False
#
#                 ESTADOCIVIL_Divorciado (a) / Separado (a)  \
# TRANSACTION ID
# 2016918                                             False
# 2016914                                             False
# 2016836                                             False
# 2016736                                             False
# 2016576                                             False
#
#                 ESTADOCIVIL_Soltero (a)  ESTADOCIVIL_Unión libre  \
# TRANSACTION ID
# 2016918                            True                    False
# 2016914                            True                    False
# 2016836                           False                     True
# 2016736                           False                     True
# 2016576                            True                    False
#
#                 ESTADOCIVIL_Viudo (a)  TIPO VIVIENDA_Familiar  \
# TRANSACTION ID
# 2016918                         False                    True
# 2016914                         False                   False
# 2016836                         False                    True
# 2016736                         False                   False
# 2016576                         False                   False
#
#                 TIPO VIVIENDA_Propia  TIPO VIVIENDA_Propia con crédito  \
# TRANSACTION ID
# 2016918                        False                             False
# 2016914                         True                             False
# 2016836                        False                             False
# 2016736                         True                             False
# 2016576                         True                             False
#
#                 ACTIVIDAD ECONÓMICA_Actividades de apoyo a la educación.  \
# TRANSACTION ID
# 2016918                                                      True
# 2016914                                                     False
# 2016836                                                     False
# 2016736                                                     False
# 2016576                                                     False
#
#                 ACTIVIDAD ECONÓMICA_Actividades no diferenciadas de los hogares individuales como productores de bienes para uso propio.  \
# TRANSACTION ID
# 2016918                                                     False
# 2016914                                                     False
# 2016836                                                     False
# 2016736                                                     False
# 2016576                                                     False
#
#                 ACTIVIDAD ECONÓMICA_Asalariados  \
# TRANSACTION ID
# 2016918                                   False
# 2016914                                   False
# 2016836                                   False
# 2016736                                   False
# 2016576                                   False
#
#                 ACTIVIDAD ECONÓMICA_Comercio al por mayor a cambio de una retribución o por contrata.  \
# TRANSACTION ID
# 2016918                                                     False
# 2016914                                                      True
# 2016836                                                     False
# 2016736                                                     False
# 2016576                                                     False
#
#                 ACTIVIDAD ECONÓMICA_Otras actividades de servicios personales n.c.p.  \
# TRANSACTION ID
# 2016918                                                     False
# 2016914                                                     False
# 2016836                                                     False
# 2016736                                                      True
# 2016576                                                     False
#
#                 ACTIVIDAD ECONÓMICA_Otros tipos de comercio al por menor no realizado en establecimientos, puestos de venta o mercados.  \
# TRANSACTION ID
# 2016918                                                     False
# 2016914                                                     False
# 2016836                                                      True
# 2016736                                                     False
# 2016576                                                      True
#
#                 ACTIVIDAD ECONÓMICA_Pensionados  \
# TRANSACTION ID
# 2016918                                   False
# 2016914                                   False
# 2016836                                   False
# 2016736                                   False
# 2016576                                   False
#
#                 ACTIVIDAD ECONÓMICA_Rentistas de Capital, solo para personas naturales.  \
# TRANSACTION ID
# 2016918                                                     False
# 2016914                                                     False
# 2016836                                                     False
# 2016736                                                     False
# 2016576                                                     False
#
#                 TIPO CONTRATO_Indefinido  TIPO CONTRATO_No Aplica  \
# TRANSACTION ID
# 2016918                             True                    False
# 2016914                            False                     True
# 2016836                             True                    False
# 2016736                             True                    False
# 2016576                            False                    False
#
#                 TIPO CONTRATO_Prestación de servicios  OCUPACIÓN_Empleado  \
# TRANSACTION ID
# 2016918                                         False               False
# 2016914                                         False               False
# 2016836                                         False                True
# 2016736                                         False                True
# 2016576                                          True               False
#
#                 OCUPACIÓN_Estudiante  OCUPACIÓN_Independiente  \
# TRANSACTION ID
# 2016918                        False                     True
# 2016914                        False                     True
# 2016836                        False                    False
# 2016736                        False                    False
# 2016576                        False                     True
#
#                 OCUPACIÓN_Pensionado / Jubilado  OCUPACIÓN_Rentista  \
# TRANSACTION ID
# 2016918                                   False               False
# 2016914                                   False               False
# 2016836                                   False               False
# 2016736                                   False               False
# 2016576                                   False               False
#
#                 OCUPACIÓN_Taxista   OCUPACIÓN_Vendedora por catalogo  \
# TRANSACTION ID
# 2016918                      False                             False
# 2016914                      False                             False
# 2016836                      False                             False
# 2016736                      False                             False
# 2016576                      False                             False
#
#                 LUGAR NACIMIENTO_Albania  LUGAR NACIMIENTO_Argentina  \
# TRANSACTION ID
# 2016918                            False                       False
# 2016914                            False                       False
# 2016836                            False                       False
# 2016736                            False                       False
# 2016576                            False                       False
#
#                 LUGAR NACIMIENTO_Armenia  LUGAR NACIMIENTO_Belgica  \
# TRANSACTION ID
# 2016918                            False                     False
# 2016914                            False                     False
# 2016836                            False                     False
# 2016736                            False                     False
# 2016576                            False                     False
#
#                 LUGAR NACIMIENTO_China  \
# TRANSACTION ID
# 2016918                          False
# 2016914                          False
# 2016836                          False
# 2016736                          False
# 2016576                          False
#
#                 LUGAR NACIMIENTO_Cocos (Keeling), Islas  \
# TRANSACTION ID
# 2016918                                           False
# 2016914                                           False
# 2016836                                           False
# 2016736                                           False
# 2016576                                           False
#
#                 LUGAR NACIMIENTO_Colombia  LUGAR NACIMIENTO_Ecuador  \
# TRANSACTION ID
# 2016918                              True                     False
# 2016914                              True                     False
# 2016836                              True                     False
# 2016736                              True                     False
# 2016576                              True                     False
#
#                 LUGAR NACIMIENTO_España  LUGAR NACIMIENTO_Estados Unidos  \
# TRANSACTION ID
# 2016918                           False                            False
# 2016914                           False                            False
# 2016836                           False                            False
# 2016736                           False                            False
# 2016576                           False                            False
#
#                 LUGAR NACIMIENTO_Honduras  LUGAR NACIMIENTO_Italia  \
# TRANSACTION ID
# 2016918                             False                    False
# 2016914                             False                    False
# 2016836                             False                    False
# 2016736                             False                    False
# 2016576                             False                    False
#
#                 LUGAR NACIMIENTO_Mexico  LUGAR NACIMIENTO_Panama  \
# TRANSACTION ID
# 2016918                           False                    False
# 2016914                           False                    False
# 2016836                           False                    False
# 2016736                           False                    False
# 2016576                           False                    False
#
#                 LUGAR NACIMIENTO_Puerto Rico  LUGAR NACIMIENTO_Venezuela  \
# TRANSACTION ID
# 2016918                                False                       False
# 2016914                                False                       False
# 2016836                                False                       False
# 2016736                                False                       False
# 2016576                                False                       False
#
#                 CLINICA_Dentix BAQ Barranquilla  \
# TRANSACTION ID
# 2016918                                   False
# 2016914                                   False
# 2016836                                   False
# 2016736                                   False
# 2016576                                   False
#
#                 CLINICA_Dentix BAQ Barranquilla Portal del Prado  \
# TRANSACTION ID
# 2016918                                                    False
# 2016914                                                     True
# 2016836                                                    False
# 2016736                                                    False
# 2016576                                                     True
#
#                 CLINICA_Dentix BGA Cañaveral  \
# TRANSACTION ID
# 2016918                                False
# 2016914                                False
# 2016836                                False
# 2016736                                False
# 2016576                                False
#
#                 CLINICA_Dentix BGA Cl 35 Bucaramanga  \
# TRANSACTION ID
# 2016918                                         True
# 2016914                                        False
# 2016836                                        False
# 2016736                                        False
# 2016576                                        False
#
#                 CLINICA_Dentix BOG Andino  \
# TRANSACTION ID
# 2016918                             False
# 2016914                             False
# 2016836                             False
# 2016736                             False
# 2016576                             False
#
#                 CLINICA_Dentix BOG Autopista 104A Bogota  \
# TRANSACTION ID
# 2016918                                            False
# 2016914                                            False
# 2016836                                            False
# 2016736                                            False
# 2016576                                            False
#
#                 CLINICA_Dentix BOG Avenida Chile  \
# TRANSACTION ID
# 2016918                                    False
# 2016914                                    False
# 2016836                                    False
# 2016736                                    False
# 2016576                                    False
#
#                 CLINICA_Dentix BOG C. C. Plaza Central  \
# TRANSACTION ID
# 2016918                                          False
# 2016914                                          False
# 2016836                                          False
# 2016736                                          False
# 2016576                                          False
#
#                 CLINICA_Dentix BOG C.C. Titan  \
# TRANSACTION ID
# 2016918                                 False
# 2016914                                 False
# 2016836                                 False
# 2016736                                 False
# 2016576                                 False
#
#                 CLINICA_Dentix BOG CC Plaza de las Américas Bogotá  \
# TRANSACTION ID
# 2016918                                                     False
# 2016914                                                     False
# 2016836                                                     False
# 2016736                                                     False
# 2016576                                                     False
#
#                 CLINICA_Dentix BOG Calle 90  \
# TRANSACTION ID
# 2016918                               False
# 2016914                               False
# 2016836                               False
# 2016736                               False
# 2016576                               False
#
#                 CLINICA_Dentix BOG Cedritos - Bogotá  \
# TRANSACTION ID
# 2016918                                        False
# 2016914                                        False
# 2016836                                        False
# 2016736                                        False
# 2016576                                        False
#
#                 CLINICA_Dentix BOG Chapinero  CLINICA_Dentix BOG Chia  \
# TRANSACTION ID
# 2016918                                False                    False
# 2016914                                False                    False
# 2016836                                False                    False
# 2016736                                False                    False
# 2016576                                False                    False
#
#                 CLINICA_Dentix BOG Colina Bogotá  \
# TRANSACTION ID
# 2016918                                    False
# 2016914                                    False
# 2016836                                    False
# 2016736                                    False
# 2016576                                    False
#
#                 CLINICA_Dentix BOG Diverplaza  CLINICA_Dentix BOG Fontibon  \
# TRANSACTION ID
# 2016918                                 False                        False
# 2016914                                 False                        False
# 2016836                                 False                        False
# 2016736                                 False                        False
# 2016576                                 False                        False
#
#                 CLINICA_Dentix BOG Galerias  CLINICA_Dentix BOG Gran Estación  \
# TRANSACTION ID
# 2016918                               False                             False
# 2016914                               False                             False
# 2016836                               False                              True
# 2016736                               False                             False
# 2016576                               False                             False
#
#                 CLINICA_Dentix BOG Hayuelos  \
# TRANSACTION ID
# 2016918                               False
# 2016914                               False
# 2016836                               False
# 2016736                               False
# 2016576                               False
#
#                 CLINICA_Dentix BOG Plaza Imperial  \
# TRANSACTION ID
# 2016918                                     False
# 2016914                                     False
# 2016836                                     False
# 2016736                                     False
# 2016576                                     False
#
#                 CLINICA_Dentix BOG Restrepo  CLINICA_Dentix BOG Santa Fe  \
# TRANSACTION ID
# 2016918                               False                        False
# 2016914                               False                        False
# 2016836                               False                        False
# 2016736                               False                        False
# 2016576                               False                        False
#
#                 CLINICA_Dentix BOG Unicentro  CLINICA_Dentix BOG Usaquen  \
# TRANSACTION ID
# 2016918                                False                       False
# 2016914                                False                       False
# 2016836                                False                       False
# 2016736                                False                       False
# 2016576                                False                       False
#
#                 CLINICA_Dentix BOG Venecia  CLINICA_Dentix CLO Av. 100 Cali  \
# TRANSACTION ID
# 2016918                              False                            False
# 2016914                              False                            False
# 2016836                              False                            False
# 2016736                              False                             True
# 2016576                              False                            False
#
#                 CLINICA_Dentix CLO Cali Chipichape  \
# TRANSACTION ID
# 2016918                                      False
# 2016914                                      False
# 2016836                                      False
# 2016736                                      False
# 2016576                                      False
#
#                 CLINICA_Dentix CLO Imbanaco  CLINICA_Dentix CLO Tulua  \
# TRANSACTION ID
# 2016918                               False                     False
# 2016914                               False                     False
# 2016836                               False                     False
# 2016736                               False                     False
# 2016576                               False                     False
#
#                 CLINICA_Dentix CTG Cartagena Cc Mallplaza  \
# TRANSACTION ID
# 2016918                                             False
# 2016914                                             False
# 2016836                                             False
# 2016736                                             False
# 2016576                                             False
#
#                 CLINICA_Dentix CUC Calle 13 Cúcuta  CLINICA_Dentix EOH Bello  \
# TRANSACTION ID
# 2016918                                      False                     False
# 2016914                                      False                     False
# 2016836                                      False                     False
# 2016736                                      False                     False
# 2016576                                      False                     False
#
#                 CLINICA_Dentix EOH Centro Medellín  \
# TRANSACTION ID
# 2016918                                      False
# 2016914                                      False
# 2016836                                      False
# 2016736                                      False
# 2016576                                      False
#
#                 CLINICA_Dentix EOH Nutibara Medellin  \
# TRANSACTION ID
# 2016918                                        False
# 2016914                                        False
# 2016836                                        False
# 2016736                                        False
# 2016576                                        False
#
#                 CLINICA_Dentix IBE Cra. 5 Ibague  \
# TRANSACTION ID
# 2016918                                    False
# 2016914                                    False
# 2016836                                    False
# 2016736                                    False
# 2016576                                    False
#
#                 CLINICA_Dentix MDE Av. Poblado Medellín  \
# TRANSACTION ID
# 2016918                                           False
# 2016914                                           False
# 2016836                                           False
# 2016736                                           False
# 2016576                                           False
#
#                 CLINICA_Dentix MDE Envigado  \
# TRANSACTION ID
# 2016918                               False
# 2016914                               False
# 2016836                               False
# 2016736                               False
# 2016576                               False
#
#                 CLINICA_Dentix MDE Fabricato Multialiado  \
# TRANSACTION ID
# 2016918                                            False
# 2016914                                            False
# 2016836                                            False
# 2016736                                            False
# 2016576                                            False
#
#                 CLINICA_Dentix MDE Itagüi Mayorca  \
# TRANSACTION ID
# 2016918                                     False
# 2016914                                     False
# 2016836                                     False
# 2016736                                     False
# 2016576                                     False
#
#                 CLINICA_Dentix MTR Montería  \
# TRANSACTION ID
# 2016918                               False
# 2016914                               False
# 2016836                               False
# 2016736                               False
# 2016576                               False
#
#                 CLINICA_Dentix MZL Cra. 23 Manizales  \
# TRANSACTION ID
# 2016918                                        False
# 2016914                                        False
# 2016836                                        False
# 2016736                                        False
# 2016576                                        False
#
#                 CLINICA_Dentix NVA Neiva  CLINICA_Dentix PEI Pereira  \
# TRANSACTION ID
# 2016918                            False                       False
# 2016914                            False                       False
# 2016836                            False                       False
# 2016736                            False                       False
# 2016576                            False                       False
#
#                 CLINICA_Dentix PPN Popayán  \
# TRANSACTION ID
# 2016918                              False
# 2016914                              False
# 2016836                              False
# 2016736                              False
# 2016576                              False
#
#                 CLINICA_Dentix PPN Popayán Campanario  \
# TRANSACTION ID
# 2016918                                         False
# 2016914                                         False
# 2016836                                         False
# 2016736                                         False
# 2016576                                         False
#
#                 CLINICA_Dentix PSO Pasto  CLINICA_Dentix SMR Santa Marta  \
# TRANSACTION ID
# 2016918                            False                           False
# 2016914                            False                           False
# 2016836                            False                           False
# 2016736                            False                           False
# 2016576                            False                           False
#
#                 CLINICA_Dentix TUN Tunja  CLINICA_Dentix VUP Valledupar  \
# TRANSACTION ID
# 2016918                            False                          False
# 2016914                            False                          False
# 2016836                            False                          False
# 2016736                            False                          False
# 2016576                            False                          False
#
#                 CLINICA_Dentix VVC Primavera Villavicencio   ESTRATO  \
# TRANSACTION ID
# 2016918                                              False  1.596071
# 2016914                                              False  0.631589
# 2016836                                              False -0.332892
# 2016736                                              False  0.631589
# 2016576                                              False  0.631589
#
#                    SCORE  CUOTA DE CREDITOS  TOTAL EGRESOS   ACTIVOS  PLAZO  \
# TRANSACTION ID
# 2016918        -0.497084          -0.008909      -0.009082  1.683621     36
# 2016914         1.450843          -0.008914      -0.009089 -0.846057     36
# 2016836        -0.687861          -0.008914      -0.009020 -0.737642     18
# 2016736         0.557206          -0.008877      -0.008977 -0.846057     36
# 2016576        -1.963050          -0.008904      -0.009076 -0.846057     36
#
#                     TASA  CUOTAMENSUAL  NIVEL ESTUDIOS_ORD  PROFESION_FREQ  \
# TRANSACTION ID
# 2016918         0.171785     -0.193257            0.842079        0.220835
# 2016914         0.171785     -0.193264           -0.995517       -0.348914
# 2016836         0.171785     -0.193267           -0.995517       -0.931155
# 2016736         0.171785     -0.193266           -0.995517       -0.495017
# 2016576         0.171785     -0.193267            0.842079        0.220835
#
#                 CIUDAD_FREQ  COMERCIAL_FREQ  DEPARTAMENTO_FREQ
# TRANSACTION ID
# 2016918           -0.542495        0.977167          -0.442162
# 2016914           -0.795561        1.627940          -0.505167
# 2016836            1.518785       -0.584690           1.470026
# 2016736           -0.450153        1.003198          -0.565021
# 2016576           -0.445501        2.651824          -0.505167

# %% [markdown]
# ### 2.2 Supuestos de Regresión

# %% [markdown]
# #### 2.2.1 Linealidad

# %% [markdown]
# La relación entre la variable dependiente (MONTO APROBADO) y los predictores debe ser lineal en los parámetros.

# %%
features = df0.select_dtypes(include=['int', 'float'])
features
# Out:
#                 INGRESOS FIJOS_YJ  TOTAL INGRESOS_YJ  \
# TRANSACTION ID
# 2016918                  1.550697           1.659905
# 2016914                  1.910448           1.884618
# 2016836                 -1.610168          -3.012882
# 2016736                  0.101804           0.675282
# 2016576                  1.753045           1.696270
# ...                           ...                ...
# 2047579                  0.101804          -0.468450
# 2047954                 -0.458372          -1.270907
# 2047975                  1.691614           1.621816
# 2049352                  0.664213           0.304582
# 2049778                 -0.721404          -1.658182
#
#                 GASTOS DE SOSTENIMIENTO_YJ  MONTO PREAPROBADO_YJ  \
# TRANSACTION ID
# 2016918                          -1.342884              2.274419
# 2016914                          -2.106196              0.587438
# 2016836                           0.926897             -1.333679
# 2016736                           1.123095             -0.430452
# 2016576                          -1.094328             -0.835670
# ...                                    ...                   ...
# 2047579                           0.694852             -0.955496
# 2047954                           0.694852              0.644273
# 2047975                           0.027407              0.310836
# 2049352                           0.694852             -0.724307
# 2049778                           0.027407              0.344002
#
#                 MONTO APROBADO_YJ  MONTO DESEMBOLSO_YJ  SEGURO_YJ   AVAL_YJ  \
# TRANSACTION ID
# 2016918                  2.274626             2.274398   2.274323  2.172652
# 2016914                  0.587502             0.587471   0.587420  0.935561
# 2016836                 -1.333696            -1.333657  -1.333466 -0.703152
# 2016736                 -0.430443            -0.430414  -0.430477  0.103713
# 2016576                 -0.835676            -0.835637  -0.835645 -0.249351
# ...                           ...                  ...        ...       ...
# 2047579                 -0.955505            -0.955464  -0.955695 -0.356493
# 2047954                  0.644340             0.644304   0.644305  0.979841
# 2047975                  0.310882             0.310872   0.310945  0.716695
# 2049352                 -0.724309            -0.724272  -0.724147 -0.150952
# 2049778                  0.344050             0.344037   0.344085  0.743182
#
#                  ESTRATO     SCORE  CUOTA DE CREDITOS  TOTAL EGRESOS  \
# TRANSACTION ID
# 2016918         1.596071 -0.497084          -0.008909      -0.009082
# 2016914         0.631589  1.450843          -0.008914      -0.009089
# 2016836        -0.332892 -0.687861          -0.008914      -0.009020
# 2016736         0.631589  0.557206          -0.008877      -0.008977
# 2016576         0.631589 -1.963050          -0.008904      -0.009076
# ...                  ...       ...                ...            ...
# 2047579         0.631589  1.922764          -0.008914      -0.009034
# 2047954         0.631589 -0.717983          -0.008914      -0.009034
# 2047975        -1.297374 -0.236022          -0.008910      -0.009059
# 2049352         0.631589  0.245940          -0.008904      -0.009027
# 2049778        -1.297374 -0.888678          -0.008895      -0.009048
#
#                  ACTIVOS  PLAZO      TASA  CUOTAMENSUAL  NIVEL ESTUDIOS_ORD  \
# TRANSACTION ID
# 2016918         1.683621     36  0.171785     -0.193257            0.842079
# 2016914        -0.846057     36  0.171785     -0.193264           -0.995517
# 2016836        -0.737642     18  0.171785     -0.193267           -0.995517
# 2016736        -0.846057     36  0.171785     -0.193266           -0.995517
# 2016576        -0.846057     36  0.171785     -0.193267            0.842079
# ...                  ...    ...       ...           ...                 ...
# 2047579        -0.846057     12  0.131465     -0.193265           -0.995517
# 2047954        -0.846057     30  0.131465     -0.193263           -0.995517
# 2047975        -0.701504     30  0.131465     -0.193264           -0.382985
# 2049352        -0.846057     12  0.131465     -0.193265           -0.995517
# 2049778        -0.846057     18  0.131465     -0.193263           -1.608049
#
#                 PROFESION_FREQ  CIUDAD_FREQ  COMERCIAL_FREQ  DEPARTAMENTO_FREQ
# TRANSACTION ID
# 2016918               0.220835    -0.542495        0.977167          -0.442162
# 2016914              -0.348914    -0.795561        1.627940          -0.505167
# 2016836              -0.931155     1.518785       -0.584690           1.470026
# 2016736              -0.495017    -0.450153        1.003198          -0.565021
# 2016576               0.220835    -0.445501        2.651824          -0.505167
# ...                        ...          ...             ...                ...
# 2047579               1.392377    -0.450153        1.593232          -0.565021
# 2047954              -0.807863    -0.450153        1.593232          -0.565021
# 2047975              -0.495017     1.518785        0.152854           1.470026
# 2049352               1.392377    -0.542495        2.781979          -0.442162
# 2049778               1.392377    -0.702987        0.031376          -0.895553
#
# [34156 rows x 21 columns]

# %%
df_sample = df0.sample(10000, random_state=42)

n = len(features)
ncols = 3
nrows = (n // ncols) + 1

fig, axs = plt.subplots(nrows, ncols, figsize=(15, 4*nrows))
axs = axs.flatten()

for i, col in enumerate(features):
    axs[i].hexbin(
        df_sample[col], 
        df_sample['MONTO APROBADO_YJ'], 
        gridsize=35, 
        cmap='Blues'
    )
    axs[i].set_title(f"Hexbin: Monto vs {col}")
    axs[i].set_xlabel(col)
    axs[i].set_ylabel("Monto")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 7
#       4 ncols = 3
#       5 nrows = (n // ncols) + 1
# ----> 7 fig, axs = plt.subplots(nrows, ncols, figsize=(15, 4*nrows))
#       8 axs = axs.flatten()
#      10 for i, col in enumerate(features):
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\pyplot.py:1770, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1625 """
#    1626 Create a figure and a set of subplots.
#    1627
#    (...)   1767
#    1768 """
#    1769 fig = figure(**fig_kw)
# -> 1770 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1771                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1772                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1773                    width_ratios=width_ratios)
#    1774 return fig, axs
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\figure.py:919, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     916     gridspec_kw['width_ratios'] = width_ratios
#     918 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
# --> 919 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     920                   subplot_kw=subplot_kw)
#     921 return axs
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\gridspec.py:283, in GridSpecBase.subplots(self, sharex, sharey, squeeze, subplot_kw)
#     281         subplot_kw["sharex"] = shared_with[sharex]
#     282         subplot_kw["sharey"] = shared_with[sharey]
# --> 283         axarr[row, col] = figure.add_subplot(
#     284             self[row, col], **subplot_kw)
#     286 # turn off redundant tick labeling
#     287 if sharex in ["col", "all"]:
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\figure.py:768, in FigureBase.add_subplot(self, *args, **kwargs)
#     766         args = tuple(map(int, str(args[0])))
#     767     projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 768     ax = projection_class(self, *args, **pkw)
#     769     key = (projection_class, pkw)
#     770 return self._add_axes_internal(ax, key)
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\axes\_base.py:704, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     700 # The subplotspec needs to be set after the figure (so that
#     701 # figure-level subplotpars are taken into account), but the figure
#     702 # needs to be set after self._position is initialized.
#     703 if subplotspec:
# --> 704     self.set_subplotspec(subplotspec)
#     705 else:
#     706     self._subplotspec = None
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\axes\_base.py:836, in _AxesBase.set_subplotspec(self, subplotspec)
#     834 """Set the `.SubplotSpec`. associated with the subplot."""
#     835 self._subplotspec = subplotspec
# --> 836 self._set_position(subplotspec.get_position(self.get_figure(root=False)))
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\gridspec.py:656, in SubplotSpec.get_position(self, figure)
#     653 nrows, ncols = gridspec.get_geometry()
#     654 rows, cols = np.unravel_index([self.num1, self.num2], (nrows, ncols))
#     655 fig_bottoms, fig_tops, fig_lefts, fig_rights = \
# --> 656     gridspec.get_grid_positions(figure)
#     658 fig_bottom = fig_bottoms[rows].min()
#     659 fig_top = fig_tops[rows].max()
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\gridspec.py:177, in GridSpecBase.get_grid_positions(self, fig)
#     175 cell_heights = [r * norm for r in self._row_height_ratios]
#     176 sep_heights = [0] + ([sep_h] * (nrows-1))
# --> 177 cell_hs = np.cumsum(np.column_stack([sep_heights, cell_heights]).flat)
#     179 # calculate accumulated widths of rows
#     180 cell_w = tot_width / (ncols + wspace*(ncols-1))
#
# File D:\CodingTools\Python\Lib\site-packages\numpy\_core\fromnumeric.py:2955, in cumsum(a, axis, dtype, out)
#    2879 @array_function_dispatch(_cumsum_dispatcher)
#    2880 def cumsum(a, axis=None, dtype=None, out=None):
#    2881     """
#    2882     Return the cumulative sum of the elements along a given axis.
#    2883
#    (...)   2953
#    2954     """
# -> 2955     return _wrapfunc(a, 'cumsum', axis=axis, dtype=dtype, out=out)
#
# File D:\CodingTools\Python\Lib\site-packages\numpy\_core\fromnumeric.py:54, in _wrapfunc(obj, method, *args, **kwds)
#      52 bound = getattr(obj, method, None)
#      53 if bound is None:
# ---> 54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
#      57     return bound(*args, **kwds)
#
# File D:\CodingTools\Python\Lib\site-packages\numpy\_core\fromnumeric.py:46, in _wrapit(obj, method, *args, **kwds)
#      43 # As this already tried the method, subok is maybe quite reasonable here
#      44 # but this follows what was done before. TODO: revisit this.
#      45 arr, = conv.as_arrays(subok=False)
# ---> 46 result = getattr(arr, method)(*args, **kwds)
#      48 return conv.wrap(result, to_scalar=False)
#
# KeyboardInterrupt:
# Error in callback <function _draw_all_if_interactive at 0x00000145494B6660> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\pyplot.py:279, in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\backend_bases.py:1891, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1889 if not self._is_idle_drawing:
#    1890     with self._idle_draw_cntx():
# -> 1891         self.draw(*args, **kwargs)
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\backends\backend_agg.py:377, in FigureCanvasAgg.draw(self)
#     375 def draw(self):
#     376     # docstring inherited
# --> 377     self.renderer = self.get_renderer()
#     378     self.renderer.clear()
#     379     # Acquire a lock on the shared font cache.
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\backends\backend_agg.py:392, in FigureCanvasAgg.get_renderer(self)
#     390 reuse_renderer = (self._lastKey == key)
#     391 if not reuse_renderer:
# --> 392     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     393     self._lastKey = key
#     394 return self.renderer
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\backends\backend_agg.py:69, in RendererAgg.__init__(self, width, height, dpi)
#      67 self.width = width
#      68 self.height = height
# ---> 69 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      70 self._filter_renderers = []
#      72 self._update_methods()
#
# MemoryError: bad allocation
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\backend_bases.py:2147, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2142 layout_engine = self.figure.get_layout_engine()
#    2143 if layout_engine is not None or bbox_inches == "tight":
#    2144     # we need to trigger a draw before printing to make sure
#    2145     # CL works.  "tight" also needs a draw to get the right
#    2146     # locations:
# -> 2147     renderer = _get_renderer(
#    2148         self.figure,
#    2149         functools.partial(
#    2150             print_method, orientation=orientation)
#    2151     )
#    2152     # we do this instead of `self.figure.draw_without_rendering`
#    2153     # so that we can inject the orientation
#    2154     with getattr(renderer, "_draw_disabled", nullcontext)():
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\backend_bases.py:1574, in _get_renderer(figure, print_method)
#    1571     print_method = stack.enter_context(
#    1572         figure.canvas._switch_canvas_and_return_print_method(fmt))
#    1573 try:
# -> 1574     print_method(io.BytesIO())
#    1575 except Done as exc:
#    1576     renderer, = exc.args
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\backend_bases.py:2040, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2036     optional_kws = {  # Passed by print_figure for other renderers.
#    2037         "dpi", "facecolor", "edgecolor", "orientation",
#    2038         "bbox_inches_restore"}
#    2039     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042 else:  # Let third-parties do as they see fit.
#    2043     print_method = meth
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\backends\backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)    479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\backends\backend_agg.py:429, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     424 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     425     """
#     426     Draw the canvas, then save it using `.image.imsave` (to which
#     427     *pil_kwargs* and *metadata* are forwarded).
#     428     """
# --> 429     FigureCanvasAgg.draw(self)
#     430     mpl.image.imsave(
#     431         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\backends\backend_agg.py:377, in FigureCanvasAgg.draw(self)
#     375 def draw(self):
#     376     # docstring inherited
# --> 377     self.renderer = self.get_renderer()
#     378     self.renderer.clear()
#     379     # Acquire a lock on the shared font cache.
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\backends\backend_agg.py:392, in FigureCanvasAgg.get_renderer(self)
#     390 reuse_renderer = (self._lastKey == key)
#     391 if not reuse_renderer:
# --> 392     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     393     self._lastKey = key
#     394 return self.renderer
#
# File D:\CodingTools\Python\Lib\site-packages\matplotlib\backends\backend_agg.py:69, in RendererAgg.__init__(self, width, height, dpi)
#      67 self.width = width
#      68 self.height = height
# ---> 69 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      70 self._filter_renderers = []
#      72 self._update_methods()
#
# MemoryError: bad allocation

# %% [markdown]
# #### 2.2.2 Independencia de los Errores

# %% [markdown]
# Los residuos deben ser independientes entre sí; es decir, el error de una observación no afecta al siguiente.

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df0.corr(), annot=False, cmap="coolwarm", center=0)
plt.title("Matriz de Correlaciones")
plt.show()

# %% [markdown]
# ##### Modelo OLS preliminar

# %%
X_ols = sm.add_constant(df0[features])
y_ols = df0[target]

ols_model = sm.OLS(y_ols, X_ols).fit()
print(ols_model.summary())

# %%
resid = ols_model.resid
fitted = ols_model.fittedvalues

# %% [markdown]
# #### 2.2.3 Homocedasticidad

# %% [markdown]
# La varianza de los residuos debe ser constante para todos los valores predichos.

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x=fitted, y=resid, alpha=0.5)
plt.axhline(0, color='red')
plt.title("Residuos vs Ajustados")
plt.show()

from statsmodels.stats.diagnostic import het_breuschpagan
bp = het_breuschpagan(resid, X_ols)
labels = ["LM", "LM p-val", "F", "F p-val"]
dict(zip(labels, bp))

# %% [markdown]
# #### 2.2.4 Normalidad de los Errores

# %% [markdown]
# Los residuos deben seguir una distribución normal para que las inferencias sobre los coeficientes sean válidas.

# %%
sns.histplot(resid, kde=True)
plt.title("Distribución de Residuos (Preliminar)")
plt.show()

sm.qqplot(resid, line="s")
plt.title("QQ-Plot Residuos")
plt.show()

from scipy.stats import shapiro
stat, p = shapiro(resid)
print("Shapiro–Wilk p-value:", p)

# %% [markdown]
# ### 3. División de Datos

# %%
df_fechas = pd.read_excel("../../data/raw/BaseDentix.xlsx")
cols_keep = ["TRANSACTION ID", "FECHA SOLICITUD"]
df_fechas = df_fechas[cols_keep].copy()
df_fechas.head()

# %%
id_col = "TRANSACTION ID"
fecha_col = "FECHA SOLICITUD"

df_model = df0.copy()

df_merged = df0.merge(
    df_fechas,
    how="inner",
    on=id_col
)

# %%
df_merged[fecha_col] = pd.to_datetime(df_merged[fecha_col], errors="coerce")
df_merged = df_merged.sort_values('FECHA SOLICITUD')

# %%
cols_to_drop = [
    'PLAZO', 'TASA', 'CUOTAMENSUAL', 'CUOTA DE CREDITOS'
    
]
df_merged = df_merged.drop(columns = cols_to_drop)
df_merged = df_merged.dropna(subset=[fecha_col])

# %%
print(list(df_merged.columns))

# %%
split = int(len(df_merged) * 0.8)

train = df_merged.iloc[:split].copy()
test  = df_merged.iloc[split:].copy()

# %%
datetime_cols = train.select_dtypes(include=["datetime64[ns]"]).columns.tolist()

X_train = train.drop(columns=["target_mora30"] + datetime_cols)
y_train = train["target_mora30"]

X_test = test.drop(columns=["target_mora30"] + datetime_cols)
y_test = test["target_mora30"]

# %% [markdown]
# ## 4. Modelos

# %% [markdown]
# ### 4.1 Regresión Lineal Base

# %% [markdown]
# ### 4.2 Regresión Robusta (Huber)

# %% [markdown]
# ### 4.3 Ridge / Lasso

# %% [markdown]
# ## 5. Métricas

# %%
def report_metrics(y_true, y_pred):
    print(f"MAE : {mean_absolute_error(y_true, y_pred):,.2f}")
    print(f"RMSE: {np.sqrt(mean_squared_error(y_true, y_pred)):,.2f}")
    print(f"R²  : {r2_score(y_true, y_pred):.4f}")

print("===== LINEAR =====")
report_metrics(y_test, y_pred_lin)

print("\n===== HUBER =====")
report_metrics(y_test, y_pred_huber)

print("\n===== RIDGE =====")
report_metrics(y_test, y_pred_ridge)

print("\n===== LASSO =====")
report_metrics(y_test, y_pred_lasso)

# %%
f1_scores = 2 * (precision * recall) / (precision + recall)
f1_scores = np.nan_to_num(f1_scores, nan=-1)

idx_opt = f1_scores.argmax()
threshold_f1 = thresholds[idx_opt]

threshold_f1, precision[idx_opt], recall[idx_opt], f1_scores[idx_opt]

# %% [markdown]
# ## 6. Diagnóstico Estadístico
